# %%
### Test running PIL package ----------------------------------------------------
from PIL import Image
from pylab import *

# Importing Image
pil_im = Image.open('Images/azadi_square.jpg')
imshow(pil_im)
show()

# Converting Image to grayscale
pil_im_gs = Image.open('Images/azadi_square.jpg').convert('L')
imshow(array(pil_im_gs))
show()


# Copy pasting regions
box = (400,400,1000,1000)
region = pil_im.crop(box)
region = region.transpose(Image.ROTATE_180)
pil_im.paste(region,box)
imshow(pil_im)
show()

# Resize and rotate
out = pil_im.resize((128,128))
imshow(out)
show()
out = pil_im.rotate(45)
imshow(out)
show()

# %%
### Plotting Images, Point and Lines

# read image to array
im = array(Image.open('Images/azadi_square.jpg'))

# plot the image
imshow(im)

# some points
x = [100,100,400,400]
y = [200,500,200,500]

# plot the points with red star-markers
plot(x,y,'r*')

# line plot connecting the first two points
plot(x[:2],y[:2])

# add title and show the plot
title('Plotting: "azadi_square.jpg"')
axis('off')
show()
